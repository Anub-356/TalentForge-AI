# %% [markdown]
# # 🎯 TalentForge AI - Interactive Sandbox Evaluation
#
# Welcome to the official cloud sandbox for **TalentForge AI** (Redrob India Runs Data & AI Challenge).
# This notebook demonstrates our $O(N \log K)$ streaming min-heap ranking engine running locally on sample candidate profiles with zero external API dependencies.

# %%
# !git clone https://github.com/Anub-356/TalentForge-AI.git
# %cd TalentForge-AI

# %%
# !python rank.py --candidates ./samples/sample_candidates.jsonl --out ./sandbox_submission.csv
# !cat ./sandbox_submission.csv
